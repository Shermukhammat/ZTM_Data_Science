# %% [markdown]
# <a href="https://colab.research.google.com/github/SHermukhammadjon/Data_Science_Zero_to_Mastery/blob/main/Matplotlib/introduction_to_Matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Introduction Matplotlib

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
plt.plot([1, 2, 3, 4])
plt.show()

# %%
x = [1, 2, 3, 4]
y = [11, 22, 33, 44]
plt.plot(x, y)
plt.show()

# %%
# 1st method
fig = plt.figure() # ceates a figure
ax = fig.add_subplot() # adds some axes
plt.show()

# %%
# 2nd method
fig = plt.figure() # creates a figure
ax = fig.add_axes([1, 1, 1, 1])
ax.plot(x, y) # add some data
plt.show()

# %%
# 3rd method (recommendet)
fig, ax = plt.subplots()
ax.plot(x, [50, 100, 200, 350]) # ass some data
plt.show()

# %% [markdown]
# ---
#
#
# # Anatomy Of A Matplotlib Figure
#
#
# ---
#
#
# <img src='https://drive.google.com/uc?id=1yXHO2lusDbSZB5jPHL6Ijdgi6Ep4AjFu'>
# <img src='https://drive.google.com/uc?id=1zTPykifcX8T9RTduFHuyMIZ79bTIeDHf'>

# %% [markdown]
# ### MAtpotlib example workflow

# %%
# 0. import matplotlib and get it ready for plotting in Jupyter
# %matplotlib inline
import matplotlib.pyplot as plt

# 1. Prepare data
x = [1, 2, 3, 4]
y = [11, 22, 40, 50]

# 2. Setup plot
fig, ax = plt.subplots(figsize = (10, 7)) #width and height

# 3. plot data
ax.plot(x, y)

# 4. Customize plot
ax.set(title = "Simple Plot", xlabel = "X axis", ylabel = "Y axis" )

# 5. Save & show (you save the whole figure)
fig.savefig('sample-plot.png')
plt.show()
